# %%
# %load symmetric_encryption.py
#!/usr/bin/env/python3

import urllib.request
from Crypto.Cipher import AES
import binascii
import base64
import random
import os
import zlib

################################################################################
# CS 284 Padding Utility Functions
################################################################################

# s is a bytearray to pad, k is blocklength
# you won't need to change the block length
def cmsc284pad(s,k=16):
  if k > 255:
    print("pkcs7pad: padding block length must be less than 256")
    return bytearray()
  n = k - (len(s) % k)
  if n == 0:
    n = k
  for i in range(1,n+1):
    s.extend([i])
  return s

# s is bytes to pad, k is blocklength
# you won't need to change the block length
def cmsc284padbytes(s,k=16):
  if k > 255:
    raise Exception("pkcs7pad: padding block length must be less than 256")
  n = k - (len(s) % k)
  if n == 0:
    n = k
  for i in range(1,n+1):
    s += chr(i).encode("utf-8")
  return s

# s is bytes to unpad, k is blocklength
# you won't need to change the block length
def cmsc284unpad(s,k=16):
  if not cmsc284checkpadding(s,k):
    print("cmsc284unpad: invalid padding")
    return b''
  n = s[len(s)-1]
  return s[:len(s)-n]

# checks padding on s and returns a boolean
# you won't need to change the block length
def cmsc284checkpadding(s,k=16):
  if(len(s) == 0):
    #print("Invalid padding: String zero length"%k) 
    return False
  if(len(s)%k != 0): 
    #print("Invalid padding: String is not multiple of %d bytes"%k) 
    return False
  n = s[len(s)-1]
  if n > k or n == 0:
    return False
  else: 
    for i in range(n):
      if s[len(s)-1-i] != (n-i):
        return False
  return True

################################################################################
# Function for querying the server
################################################################################

PPS2SERVER = "http://cryptoclass.cs.uchicago.edu/"
def make_query(task, cnetid, query):
  DEBUG = False
  if DEBUG:
    print("making a query")
    print("Task:", task)
    print("CNET ID:", cnetid)
    print("Query:", query)
  if (type(query) is bytearray) or (type(query) is bytes):
    url = PPS2SERVER + urllib.parse.quote_plus(task) + "/" + urllib.parse.quote_plus(cnetid) + "/" + urllib.parse.quote_plus(base64.urlsafe_b64encode(query)) + "/"
  else:
    url = PPS2SERVER + urllib.parse.quote_plus(task) + "/" + urllib.parse.quote_plus(cnetid) + "/" + urllib.parse.quote_plus(base64.urlsafe_b64encode(query.encode('utf-8'))) + "/"
  if DEBUG:
    print("Querying:", url)

  with urllib.request.urlopen(url) as response:
    raw_answer = response.read()
    answer = base64.urlsafe_b64decode(raw_answer)
    if DEBUG:
      print("Answer:", answer)
    return answer
  return None


################################################################################
# Problem 1 SOLUTION
################################################################################

def problem1(cnetid):
  return b''


################################################################################
# Problem 2 SOLUTION
################################################################################

def problem2(cnetid):
  return b''


################################################################################
# Problem 3 SOLUTION
################################################################################

def problem3(cnetid):
  return b''


################################################################################
# Problem 4 SOLUTION
################################################################################

def problem4(cnetid):
  return b''


################################################################################
# Problem 5 SOLUTION
################################################################################

def problem5(cnetid):
  return b''

################################################################################
# Problem 6 SOLUTION
################################################################################

def problem6(cnetid):
  return b''

# %%
len('password=;userdata=')
# Out:
# 19

# %%
ctext = make_query('six', 'ruolinzheng', '')
len(ctext)
# Out:
# 59

# %%
flag_len = len(ctext) - len('password=;userdata=')
flag_len
# Out:
# 40

# %%
for b in [b'donutsdonuts', b'donutsdonutz', b'donutsabdonutsa',
         b'donutsabdonutsy']:
  print(len(b), len(zlib.compress(b)))
# Out:
# 12 16
# 12 17
# 15 18
# 15 19

# %%
# if guess_byte matches flag_byte
# the ctext that comes back should be shorter
for byte in range(256):
  query = b'password=' + bytes([byte])
  ctext = make_query('six', 'ruolinzheng', query)
  print(query, len(ctext))
# Out:
# b'password=\x00' 63
# b'password=\x01' 63
# b'password=\x02' 63
# b'password=\x03' 63
# b'password=\x04' 63
# b'password=\x05' 63
# b'password=\x06' 63
# b'password=\x07' 63
# b'password=\x08' 63
# b'password=\t' 63
# b'password=\n' 63
# b'password=\x0b' 63
# b'password=\x0c' 63
# b'password=\r' 63
# b'password=\x0e' 63
# b'password=\x0f' 63
# b'password=\x10' 63
# b'password=\x11' 63
# b'password=\x12' 63
# b'password=\x13' 63
# b'password=\x14' 63
# b'password=\x15' 63
# b'password=\x16' 63
# b'password=\x17' 63
# b'password=\x18' 63
# b'password=\x19' 63
# b'password=\x1a' 63
# b'password=\x1b' 63
# b'password=\x1c' 63
# b'password=\x1d' 63
# b'password=\x1e' 63
# b'password=\x1f' 63
# b'password= ' 63
# b'password=!' 63
# b'password="' 63
# b'password=#' 63
# b'password=$' 63
# b'password=%' 63
# b'password=&' 63
# b"password='" 63
# b'password=(' 63
# b'password=)' 63
# b'password=*' 63
# b'password=+' 63
# b'password=,' 63
# b'password=-' 63
# b'password=.' 63
# b'password=/' 63
# b'password=0' 63
# b'password=1' 63
# b'password=2' 63
# b'password=3' 63
# b'password=4' 63
# b'password=5' 63
# b'password=6' 63
# b'password=7' 63
# b'password=8' 63
# b'password=9' 63
# b'password=:' 63
# b'password=;' 63
# b'password=<' 63
# b'password==' 63
# b'password=>' 63
# b'password=?' 63
# b'password=@' 63
# b'password=A' 63
# b'password=B' 63
# b'password=C' 63
# b'password=D' 63
# b'password=E' 63
# b'password=F' 63
# b'password=G' 63
# b'password=H' 63
# b'password=I' 63
# b'password=J' 63
# b'password=K' 63
# b'password=L' 63
# b'password=M' 63
# b'password=N' 63
# b'password=O' 63
# b'password=P' 63
# b'password=Q' 63
# b'password=R' 63
# b'password=S' 63
# b'password=T' 63
# b'password=U' 63
# b'password=V' 63
# b'password=W' 63
# b'password=X' 63
# b'password=Y' 63
# b'password=Z' 63
# b'password=[' 63
# b'password=\\' 63
# b'password=]' 63
# b'password=^' 63
# b'password=_' 63
# b'password=`' 63
# b'password=a' 62
# b'password=b' 63
# b'password=c' 63
# b'password=d' 63
# b'password=e' 63
# b'password=f' 63
# b'password=g' 63
# b'password=h' 63
# b'password=i' 63
# b'password=j' 63
# b'password=k' 63
# b'password=l' 63
# b'password=m' 63
# b'password=n' 63
# b'password=o' 63
# b'password=p' 63
# b'password=q' 63
# b'password=r' 63
# b'password=s' 63
# b'password=t' 63
# b'password=u' 63
# b'password=v' 63
# b'password=w' 63
# b'password=x' 63
# b'password=y' 63
# b'password=z' 63
# b'password={' 63
# b'password=|' 63
# b'password=}' 63
# b'password=~' 63
# b'password=\x7f' 63
# b'password=\x80' 63
# b'password=\x81' 63
# b'password=\x82' 63
# b'password=\x83' 63
# b'password=\x84' 63
# b'password=\x85' 63
# b'password=\x86' 63
# b'password=\x87' 63
# b'password=\x88' 63
# b'password=\x89' 63
# b'password=\x8a' 63
# b'password=\x8b' 63
# b'password=\x8c' 63
# b'password=\x8d' 63
# b'password=\x8e' 63
# b'password=\x8f' 63
# b'password=\x90' 63
# b'password=\x91' 63
# b'password=\x92' 63
# b'password=\x93' 63
# b'password=\x94' 63
# b'password=\x95' 63
# b'password=\x96' 63
# b'password=\x97' 63
# b'password=\x98' 63
# b'password=\x99' 63
# b'password=\x9a' 63
# b'password=\x9b' 63
# b'password=\x9c' 63
# b'password=\x9d' 63
# b'password=\x9e' 63
# b'password=\x9f' 63
# b'password=\xa0' 63
# b'password=\xa1' 63
# b'password=\xa2' 63
# b'password=\xa3' 63
# b'password=\xa4' 63
# b'password=\xa5' 63
# b'password=\xa6' 63
# b'password=\xa7' 63
# b'password=\xa8' 63
# b'password=\xa9' 63
# b'password=\xaa' 63
# b'password=\xab' 63
# b'password=\xac' 63
# b'password=\xad' 63
# b'password=\xae' 63
# b'password=\xaf' 63
# b'password=\xb0' 63
# b'password=\xb1' 63
# b'password=\xb2' 63
# b'password=\xb3' 63
# b'password=\xb4' 63
# b'password=\xb5' 63
# b'password=\xb6' 63
# b'password=\xb7' 63
# b'password=\xb8' 63
# b'password=\xb9' 63
# b'password=\xba' 63
# b'password=\xbb' 63
# b'password=\xbc' 63
# b'password=\xbd' 63
# b'password=\xbe' 63
# b'password=\xbf' 63
# b'password=\xc0' 63
# b'password=\xc1' 63
# b'password=\xc2' 63
# b'password=\xc3' 63
# b'password=\xc4' 63
# b'password=\xc5' 63
# b'password=\xc6' 63
# b'password=\xc7' 63
# b'password=\xc8' 63
# b'password=\xc9' 63
# b'password=\xca' 63
# b'password=\xcb' 63
# b'password=\xcc' 63
# b'password=\xcd' 63
# b'password=\xce' 63
# b'password=\xcf' 63
# b'password=\xd0' 63
# b'password=\xd1' 63
# b'password=\xd2' 63
# b'password=\xd3' 63
# b'password=\xd4' 63
# b'password=\xd5' 63
# b'password=\xd6' 63
# b'password=\xd7' 63
# b'password=\xd8' 63
# b'password=\xd9' 63
# b'password=\xda' 63
# b'password=\xdb' 63
# b'password=\xdc' 63
# b'password=\xdd' 63
# b'password=\xde' 63
# b'password=\xdf' 63
# b'password=\xe0' 63
# b'password=\xe1' 63
# b'password=\xe2' 63
# b'password=\xe3' 63
# b'password=\xe4' 63
# b'password=\xe5' 63
# b'password=\xe6' 63
# b'password=\xe7' 63
# b'password=\xe8' 63
# b'password=\xe9' 63
# b'password=\xea' 63
# b'password=\xeb' 63
# b'password=\xec' 63
# b'password=\xed' 63
# b'password=\xee' 63
# b'password=\xef' 63
# b'password=\xf0' 63
# b'password=\xf1' 63
# b'password=\xf2' 63
# b'password=\xf3' 63
# b'password=\xf4' 63
# b'password=\xf5' 63
# b'password=\xf6' 63
# b'password=\xf7' 63
# b'password=\xf8' 63
# b'password=\xf9' 63
# b'password=\xfa' 63
# b'password=\xfb' 63
# b'password=\xfc' 63
# b'password=\xfd' 63
# b'password=\xfe' 63
# b'password=\xff' 63

# %%
min_len = None
for b in range(256):
  byte = bytes([b])
  query = b'password=' + byte
  ctext = make_query('six', 'ruolinzheng', query)
  len_ctext = len(ctext)
  if min_len is None:
    min_len = len_ctext
  elif min_len > len_ctext:
    print(byte)
    break
# Out:
# b'a'

# %%
ctext = make_query('six', 'ruolinzheng', '')
flag_len = len(ctext) - len('password=;userdata=')
flag = bytearray()
for i in range(flag_len):
  min_len = None
  for b in range(256):
    byte = bytes([b])
    query = b'password=' + bytes(flag) + byte
    ctext = make_query('six', 'ruolinzheng', query)
    len_ctext = len(ctext)
    if min_len is None:
      min_len = len_ctext
    elif min_len > len_ctext:
      flag.append(b)
      print(i, b, byte, query)
      break
# Out:
# 0 97 b'a' b'password=a'
# 1 116 b't' b'password=at'
# 2 90 b'Z' b'password=atZ'
# 3 108 b'l' b'password=atZl'
# 4 80 b'P' b'password=atZlP'
# 5 77 b'M' b'password=atZlPM'
# 6 112 b'p' b'password=atZlPMp'
# 7 81 b'Q' b'password=atZlPMpQ'
# 8 118 b'v' b'password=atZlPMpQv'
# 9 104 b'h' b'password=atZlPMpQvh'
# 10 120 b'x' b'password=atZlPMpQvhx'
# 11 75 b'K' b'password=atZlPMpQvhxK'
# 12 107 b'k' b'password=atZlPMpQvhxKk'
# 13 90 b'Z' b'password=atZlPMpQvhxKkZ'
# 14 115 b's' b'password=atZlPMpQvhxKkZs'
# 15 115 b's' b'password=atZlPMpQvhxKkZss'
# 16 59 b';' b'password=atZlPMpQvhxKkZss;'
# 17 117 b'u' b'password=atZlPMpQvhxKkZss;u'
# 18 115 b's' b'password=atZlPMpQvhxKkZss;us'
# 19 101 b'e' b'password=atZlPMpQvhxKkZss;use'
# 20 114 b'r' b'password=atZlPMpQvhxKkZss;user'
# 21 100 b'd' b'password=atZlPMpQvhxKkZss;userd'
# 22 97 b'a' b'password=atZlPMpQvhxKkZss;userda'
# 23 116 b't' b'password=atZlPMpQvhxKkZss;userdat'
# 24 97 b'a' b'password=atZlPMpQvhxKkZss;userdata'
# 25 61 b'=' b'password=atZlPMpQvhxKkZss;userdata='
# 26 112 b'p' b'password=atZlPMpQvhxKkZss;userdata=p'
# 27 97 b'a' b'password=atZlPMpQvhxKkZss;userdata=pa'
# 28 115 b's' b'password=atZlPMpQvhxKkZss;userdata=pas'
# 29 115 b's' b'password=atZlPMpQvhxKkZss;userdata=pass'
# 30 119 b'w' b'password=atZlPMpQvhxKkZss;userdata=passw'
# 31 111 b'o' b'password=atZlPMpQvhxKkZss;userdata=passwo'
# 32 114 b'r' b'password=atZlPMpQvhxKkZss;userdata=passwor'
# 33 100 b'd' b'password=atZlPMpQvhxKkZss;userdata=password'
# 34 61 b'=' b'password=atZlPMpQvhxKkZss;userdata=password='
# 35 97 b'a' b'password=atZlPMpQvhxKkZss;userdata=password=a'
# 36 116 b't' b'password=atZlPMpQvhxKkZss;userdata=password=at'
# 37 90 b'Z' b'password=atZlPMpQvhxKkZss;userdata=password=atZ'
# 38 108 b'l' b'password=atZlPMpQvhxKkZss;userdata=password=atZl'
# 39 80 b'P' b'password=atZlPMpQvhxKkZss;userdata=password=atZlP'

# %%
flag
# Out:
# bytearray(b'atZlPMpQvhxKkZss;userdata=password=atZlP')

# %%
def problem6(cnetid):
  ctext = make_query('six', cnetid, '')
  flag_len = len(ctext) - len('password=;userdata=')
  flag = bytearray()
  for i in range(flag_len):
    min_len = None
    for b in range(256):
      byte = bytes([b])
      query = b'password=' + bytes(flag) + byte
      ctext = make_query('six', cnetid, query)
      len_ctext = len(ctext)
      if min_len is None:
        min_len = len_ctext
      elif min_len > len_ctext:
        flag.append(b)
        print(i, b, byte, query)
        break
  return flag[flag.find(b';')]

# %%
problem6('davidcash')
# Out:
# 0 73 b'I' b'password=I'
# 1 122 b'z' b'password=Iz'
# 2 70 b'F' b'password=IzF'
# 3 78 b'N' b'password=IzFN'
# 4 77 b'M' b'password=IzFNM'
# 5 113 b'q' b'password=IzFNMq'
# 6 98 b'b' b'password=IzFNMqb'
# 7 72 b'H' b'password=IzFNMqbH'
# 8 100 b'd' b'password=IzFNMqbHd'
# 9 68 b'D' b'password=IzFNMqbHdD'
# 10 79 b'O' b'password=IzFNMqbHdDO'
# 11 97 b'a' b'password=IzFNMqbHdDOa'
# 12 122 b'z' b'password=IzFNMqbHdDOaz'
# 13 49 b'1' b'password=IzFNMqbHdDOaz1'
# 14 90 b'Z' b'password=IzFNMqbHdDOaz1Z'
# 15 120 b'x' b'password=IzFNMqbHdDOaz1Zx'
# 16 59 b';' b'password=IzFNMqbHdDOaz1Zx;'
# 17 117 b'u' b'password=IzFNMqbHdDOaz1Zx;u'
# 18 115 b's' b'password=IzFNMqbHdDOaz1Zx;us'
# 19 101 b'e' b'password=IzFNMqbHdDOaz1Zx;use'
# 20 114 b'r' b'password=IzFNMqbHdDOaz1Zx;user'
# 21 100 b'd' b'password=IzFNMqbHdDOaz1Zx;userd'
# 22 97 b'a' b'password=IzFNMqbHdDOaz1Zx;userda'
# 23 116 b't' b'password=IzFNMqbHdDOaz1Zx;userdat'
# 24 97 b'a' b'password=IzFNMqbHdDOaz1Zx;userdata'
# 25 61 b'=' b'password=IzFNMqbHdDOaz1Zx;userdata='
# 26 112 b'p' b'password=IzFNMqbHdDOaz1Zx;userdata=p'
# 27 97 b'a' b'password=IzFNMqbHdDOaz1Zx;userdata=pa'
# 28 115 b's' b'password=IzFNMqbHdDOaz1Zx;userdata=pas'
# 29 115 b's' b'password=IzFNMqbHdDOaz1Zx;userdata=pass'
# 30 119 b'w' b'password=IzFNMqbHdDOaz1Zx;userdata=passw'
# 31 111 b'o' b'password=IzFNMqbHdDOaz1Zx;userdata=passwo'
# 32 114 b'r' b'password=IzFNMqbHdDOaz1Zx;userdata=passwor'
# 33 100 b'd' b'password=IzFNMqbHdDOaz1Zx;userdata=password'
# 34 61 b'=' b'password=IzFNMqbHdDOaz1Zx;userdata=password='
# 35 73 b'I' b'password=IzFNMqbHdDOaz1Zx;userdata=password=I'
# 36 122 b'z' b'password=IzFNMqbHdDOaz1Zx;userdata=password=Iz'
# 37 70 b'F' b'password=IzFNMqbHdDOaz1Zx;userdata=password=IzF'
# 38 78 b'N' b'password=IzFNMqbHdDOaz1Zx;userdata=password=IzFN'
# 39 77 b'M' b'password=IzFNMqbHdDOaz1Zx;userdata=password=IzFNM'
# bytearray(b'IzFNMqbHdDOaz1Zx;userdata=password=IzFNM')
